# %%
from backprop_demo.backprop import experiment
import importlib, backprop_demo
experiment = importlib.reload(backprop_demo.backprop).experiment

# %%
# Default args
args = dict(
    seed=1,
    lr=1,
    init_std=0.1,
    bonus=False,
    n_hidden_nodes=2,
    n_iters=10000,
    plot_before=False,
    verbose=False,
    save=False
)

# %%
experiment(**args)
# Out:
# 100% accuracy
# [[-9.92  3.99]
#  [ 6.51 -8.18]
#  [ 6.05 -7.74]]
# [[  7.33]
#  [-15.05]
#  [-14.78]]
# Took 0m:0.8s

# %%
args2 = dict(
    seed=1,
    lr=1,
    init_std=0.1,
    bonus=True,
    n_hidden_nodes=10,
    n_iters=10000,
    plot_before=False,
    verbose=False,
    save=False
)
experiment(**args2)
# Out:
# 100% accuracy
# [[ -0.63   5.31  -3.71  -2.02  -3.84  19.1    3.21   9.06   4.88  -1.13]
#  [ -1.94  -7.4    2.53   0.88  12.39 -22.67  -2.81  -6.64  -3.56   0.99]
#  [  0.98  14.01   1.21  -0.15 -11.58 -17.51  -0.49  -4.34  -1.92  -0.59]]
# [[  3.1 ]
#  [  2.33]
#  [-13.  ]
#  [ -2.74]
#  [ -0.76]
#  [-13.62]
#  [-27.43]
#  [  4.17]
#  [ 12.62]
#  [  6.3 ]
#  [ -0.24]]
# Took 0m:1.6s
